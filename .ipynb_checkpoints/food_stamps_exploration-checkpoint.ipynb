# %%
#load data

# %%
#import libraries
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib
import requests 
import pandas as pd
import dask.dataframe as pd_dd
import zipfile
import io
import wget
from shapely.geometry import Point
import geopandas as gpd
import random
import json
from fiona.crs import from_epsg
#import pysal as ps
import pylab as pl
import matplotlib.pyplot as plt

# %%
data1="/home/jinalklaulitz/Documents/capstone/Input/July 2018 Monthly LinkNYC Data - Per-AP.csv"
data2="/home/jinalklaulitz/Documents/capstone/Input/Link EBT Call Data 041219.xlsx"
data3="/home/jinalklaulitz/Documents/capstone/Input/aff_batch1/clean_batch1/food_stamps_supplemental_nutrition_assistance_program_snap.csv"
output_path="/home/jinalklaulitz/Documents/capstone/Input"

# %%
MONTHLY_LNYC_pd = pd.read_excel(data2,'EBT Call Data Per Link')
LINK_EBT_pd = pd.read_csv(data1)
food_stamps_pd = pd.read_csv(data3)

# %%
#look into dataset

# %%
food_stamps_pd.head()
# Out:
#                  id      id2  \
# 0  7950000US3603701  3603701
# 1  7950000US3603702  3603702
# 2  7950000US3603703  3603703
# 3  7950000US3603704  3603704
# 4  7950000US3603705  3603705
#
#                                            geography  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...
# 1  NYC-Bronx Community District 12--Wakefield, Wi...
# 2  NYC-Bronx Community District 10--Co-op City, P...
# 3  NYC-Bronx Community District 11--Pelham Parkwa...
# 4  NYC-Bronx Community District 3 & 6--Belmont, C...
#
#    total_estimate_households  \
# 0                      42374
# 1                      48495
# 2                      47551
# 3                      44518
# 4                      57417
#
#    households_receiving_food_stamps/snap_estimate_households  \
# 0                                               8439
# 1                                              11904
# 2                                               6714
# 3                                              11236
# 4                                              29250
#
#    percent_households_receiving_food_stamps/snap_estimate_households  \
# 0                                               19.9
# 1                                               24.5
# 2                                               14.1
# 3                                               25.2
# 4                                               50.9
#
#    households_not_receiving_food_stamps/snap_estimate_households  \
# 0                                              33935
# 1                                              36591
# 2                                              40837
# 3                                              33282
# 4                                              28167
#
#    percent_households_not_receiving_food_stamps/snap_estimate_households  \
# 0                                               80.1
# 1                                               75.5
# 2                                               85.9
# 3                                               74.8
# 4                                               49.1
#
#    total_estimate_with_one_or_more_people_in_the_household_60_years_and_over  \
# 0                                              17515
# 1                                              19175
# 2                                              22387
# 3                                              16437
# 4                                              17137
#
#    percent_estimate_with_one_or_more_people_in_the_household_60_years_and_over  \
# 0                                               41.3
# 1                                               39.5
# 2                                               47.1
# 3                                               36.9
# 4                                               29.8
#
#    ...   \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    percent_households_receiving_food_stamps/snap_estimate_work_status__families__1_worker_in_past_12_months  \
# 0                                               44.2
# 1                                               41.4
# 2                                               40.5
# 3                                               41.5
# 4                                               48.6
#
#    households_not_receiving_food_stamps/snap_estimate_work_status__families__1_worker_in_past_12_months  \
# 0                                               6871
# 1                                               9074
# 2                                               9011
# 3                                               7838
# 4                                               7795
#
#    percent_households_not_receiving_food_stamps/snap_estimate_work_status__families__1_worker_in_past_12_months  \
# 0                                               34.8
# 1                                               35.7
# 2                                               36.2
# 3                                               35.2
# 4                                               43.0
#
#    total_estimate_work_status__families__2_or_more_workers_in_past_12_months  \
# 0                                              12944
# 1                                              16831
# 2                                              14254
# 3                                              14402
# 4                                              12966
#
#    percent_estimate_work_status__families__2_or_more_workers_in_past_12_months  \
# 0                                               50.6
# 1                                               49.9
# 2                                               49.3
# 3                                               48.1
# 4                                               34.0
#
#    households_receiving_food_stamps/snap_estimate_work_status__families__2_or_more_workers_in_past_12_months  \
# 0                                               2059
# 1                                               3015
# 2                                               1249
# 3                                               2332
# 4                                               4491
#
#    percent_households_receiving_food_stamps/snap_estimate_work_status__families__2_or_more_workers_in_past_12_months  \
# 0                                               35.2
# 1                                               36.3
# 2                                               30.9
# 3                                               30.4
# 4                                               22.4
#
#    households_not_receiving_food_stamps/snap_estimate_work_status__families__2_or_more_workers_in_past_12_months  \
# 0                                              10885
# 1                                              13816
# 2                                              13005
# 3                                              12070
# 4                                               8475
#
#    percent_households_not_receiving_food_stamps/snap_estimate_work_status__families__2_or_more_workers_in_past_12_months  \
# 0                                               55.1
# 1                                               54.3
# 2                                               52.3
# 3                                               54.2
# 4                                               46.8
#
#    PUMA
# 0  3701
# 1  3702
# 2  3703
# 3  3704
# 4  3705
#
# [5 rows x 225 columns]

# %%
#create subset

# %%
#for i in list(food_stamps_pd.columns):
#    print(i)
#    print("\n")

reduced_food_stamps = food_stamps_pd[['id',
'id2',
'geography',
'total_estimate_households',
'households_receiving_food_stamps/snap_estimate_households',
'percent_households_receiving_food_stamps/snap_estimate_households',
'PUMA']]

# %%
#look into data

# %%
reduced_food_stamps.head()
# Out:
#                  id      id2  \
# 0  7950000US3603701  3603701
# 1  7950000US3603702  3603702
# 2  7950000US3603703  3603703
# 3  7950000US3603704  3603704
# 4  7950000US3603705  3603705
#
#                                            geography  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...
# 1  NYC-Bronx Community District 12--Wakefield, Wi...
# 2  NYC-Bronx Community District 10--Co-op City, P...
# 3  NYC-Bronx Community District 11--Pelham Parkwa...
# 4  NYC-Bronx Community District 3 & 6--Belmont, C...
#
#    total_estimate_households  \
# 0                      42374
# 1                      48495
# 2                      47551
# 3                      44518
# 4                      57417
#
#    households_receiving_food_stamps/snap_estimate_households  \
# 0                                               8439
# 1                                              11904
# 2                                               6714
# 3                                              11236
# 4                                              29250
#
#    percent_households_receiving_food_stamps/snap_estimate_households  PUMA
# 0                                               19.9                  3701
# 1                                               24.5                  3702
# 2                                               14.1                  3703
# 3                                               25.2                  3704
# 4                                               50.9                  3705

# %%
reduced_food_stamps.dtypes
# Out:
# id                                                                    object
# id2                                                                    int64
# geography                                                             object
# total_estimate_households                                              int64
# households_receiving_food_stamps/snap_estimate_households              int64
# percent_households_receiving_food_stamps/snap_estimate_households    float64
# PUMA                                                                   int64
# dtype: object

# %%
#load shapefile

# %%
filename = "geo_export_ba3ea3cb-cf7a-4165-a569-b8e93d5eb73e.shp"
pumashp = gpd.GeoDataFrame.from_file(output_path+"/"+filename)

# %%
pumashp.head()
# Out:
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002487
# 2  3703  2.670108e+08  303565.021099
# 3  3704  1.062129e+08   47970.901277
# 4  4015  8.105438e+07   50007.415288
#
#                                             geometry
# 0  POLYGON ((-73.89995351384715 40.91238343476548...
# 1  POLYGON ((-73.86948896192655 40.87798946841054...
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...
# 4  POLYGON ((-73.96524103510922 40.65174204697276...

# %%
pumashp.dtypes
# Out:
# puma           object
# shape_area    float64
# shape_leng    float64
# geometry       object
# dtype: object

# %%
pumashp['puma'] = pumashp.puma.astype('int64')

# %%
foodstamps_puma = reduced_food_stamps.merge(pumashp,left_on='PUMA',right_on='puma')

# %%
foodstamps_puma.head()
# Out:
#                  id      id2  \
# 0  7950000US3603701  3603701
# 1  7950000US3603702  3603702
# 2  7950000US3603703  3603703
# 3  7950000US3603704  3603704
# 4  7950000US3603705  3603705
#
#                                            geography  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...
# 1  NYC-Bronx Community District 12--Wakefield, Wi...
# 2  NYC-Bronx Community District 10--Co-op City, P...
# 3  NYC-Bronx Community District 11--Pelham Parkwa...
# 4  NYC-Bronx Community District 3 & 6--Belmont, C...
#
#    total_estimate_households  \
# 0                      42374
# 1                      48495
# 2                      47551
# 3                      44518
# 4                      57417
#
#    households_receiving_food_stamps/snap_estimate_households  \
# 0                                               8439
# 1                                              11904
# 2                                               6714
# 3                                              11236
# 4                                              29250
#
#    percent_households_receiving_food_stamps/snap_estimate_households  PUMA  \
# 0                                               19.9                  3701
# 1                                               24.5                  3702
# 2                                               14.1                  3703
# 3                                               25.2                  3704
# 4                                               50.9                  3705
#
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002487
# 2  3703  2.670108e+08  303565.021099
# 3  3704  1.062129e+08   47970.901277
# 4  3705  1.224951e+08   68657.316149
#
#                                             geometry
# 0  POLYGON ((-73.89995351384715 40.91238343476548...
# 1  POLYGON ((-73.86948896192655 40.87798946841054...
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...
# 4  POLYGON ((-73.87045508990893 40.86663286876232...

# %%
#check row count

# %%
print("table has {} rows".format(len(reduced_food_stamps.index)))
# Out:
# table has 55 rows

# %%
print("table has {} rows".format(len(pumashp.index)))
# Out:
# table has 55 rows

# %%
print("table has {} rows".format(len(foodstamps_puma.index)))
# Out:
# table has 55 rows

# %%
pumashp.crs
# Out:
# {'init': 'epsg:4326'}

# %%
pumashp.crs = {'init' :'epsg:4326'}

# %%
# Convert to a GeoDataFrame
foodstamps_puma = gpd.GeoDataFrame(foodstamps_puma, geometry="geometry")

# %%
foodstamps_puma.crs

# %%
#foodstamps_puma['test'] = foodstamps_puma['percent_households_receiving_food_stamps/snap_estimate_households']

# %%
#check shapefile

# %%
fig = pl.figure(figsize = (20,20))
ax = fig.add_subplot(111)
pumashp.plot(ax=ax, color="white", edgecolor="black", lw=1)
ax.axis('off');

# %%
#visualize percentage of households receiving foodstamps

# %%
fig = pl.figure(figsize = (18,15))
ax = fig.add_subplot(111)
foodstamps_puma.plot("percent_households_receiving_food_stamps/snap_estimate_households",ax=ax,legend=True,linewidth=1,edgecolor='black')
ax.axis('off');
ax.set_title('Percentage of households receiving foodstamps in NYC', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percentage of households receiving foodstamps in NYC')

# %%
MONTHLY_LNYC_pd.head()
# Out:
#         Site ID ﻿Activation Date  Days Since Activation    Borough  \
# 0  bx-01-116415       2017-03-06                    756      Bronx
# 1  mn-11-144674       2016-11-02                    840  Manhattan
# 2  mn-11-144673       2016-03-28                    840  Manhattan
# 3  mn-03-108238       2016-08-19                    840  Manhattan
# 4  bx-01-118956       2016-12-22                    830      Bronx
#
#    Community Board   Latitude  Longitude       Street Address  Zip Code  \
# 0              201  40.816751 -73.922955    522 MORRIS AVENUE     10451
# 1              111  40.803834 -73.936351  186 EAST 125 STREET     10035
# 2              111  40.803731 -73.936139  192 EAST 125 STREET     10035
# 3              103  40.721716 -73.993343           217 BOWERY     10002
# 4              201  40.816679 -73.916483        2882 3 AVENUE     10455
#
#    EBT Total Calls  EBT Calls Per Day
# 0             3900           5.158730
# 1             3303           3.932143
# 2             1849           2.201190
# 3             1802           2.145238
# 4             1788           2.154217

# %%
for i in list(MONTHLY_LNYC_pd.columns):
    print(i)
# Out:
# Site ID
# ﻿Activation Date
# Days Since Activation
# Borough
# Community Board
# Latitude
# Longitude
# Street Address
# Zip Code
# EBT Total Calls
# EBT Calls Per Day

# %%
#create geopanda-able longlats
MONTHLY_LNYC_pd['lonlat'] = list(zip(MONTHLY_LNYC_pd.Longitude, MONTHLY_LNYC_pd.Latitude))
MONTHLY_LNYC_pd['geometry'] = MONTHLY_LNYC_pd[['lonlat']].applymap(lambda x:Point(x))
# Convert to a GeoDataFrame
MONTHLY_LNYC_pd = gpd.GeoDataFrame(MONTHLY_LNYC_pd, geometry="geometry")

# set crs
MONTHLY_LNYC_pd.crs = {'init': 'epsg:4326'}

# %%
MONTHLY_LNYC_pd.crs
# Out:
# {'init': 'epsg:4326'}

# %%
foodstamps_puma.crs

# %%
MONTHLY_LNYC_pd.head()
# Out:
#         Site ID ﻿Activation Date  Days Since Activation    Borough  \
# 0  bx-01-116415       2017-03-06                    756      Bronx
# 1  mn-11-144674       2016-11-02                    840  Manhattan
# 2  mn-11-144673       2016-03-28                    840  Manhattan
# 3  mn-03-108238       2016-08-19                    840  Manhattan
# 4  bx-01-118956       2016-12-22                    830      Bronx
#
#    Community Board   Latitude  Longitude       Street Address  Zip Code  \
# 0              201  40.816751 -73.922955    522 MORRIS AVENUE     10451
# 1              111  40.803834 -73.936351  186 EAST 125 STREET     10035
# 2              111  40.803731 -73.936139  192 EAST 125 STREET     10035
# 3              103  40.721716 -73.993343           217 BOWERY     10002
# 4              201  40.816679 -73.916483        2882 3 AVENUE     10455
#
#    EBT Total Calls  EBT Calls Per Day                       lonlat  \
# 0             3900           5.158730  (-73.92295481, 40.81675132)
# 1             3303           3.932143  (-73.93635101, 40.80383418)
# 2             1849           2.201190      (-73.936139, 40.803731)
# 3             1802           2.145238      (-73.993343, 40.721716)
# 4             1788           2.154217  (-73.91648285, 40.81667907)
#
#                                  geometry
# 0  POINT (-73.92295480999999 40.81675132)
# 1        POINT (-73.93635101 40.80383418)
# 2            POINT (-73.936139 40.803731)
# 3            POINT (-73.993343 40.721716)
# 4  POINT (-73.91648284999999 40.81667907)

# %%
EBT_FOODSTAMPS = gpd.sjoin(MONTHLY_LNYC_pd, foodstamps_puma, op='within')
# Out:
# /home/jinalklaulitz/anaconda3/lib/python3.7/site-packages/geopandas/tools/sjoin.py:56: UserWarning: CRS of frames being joined does not match!({'init': 'epsg:4326'} != None)
#   '(%s != %s)' % (left_df.crs, right_df.crs))

# %%
EBT_FOODSTAMPS.head()
# Out:
#          Site ID ﻿Activation Date  Days Since Activation Borough  \
# 0   bx-01-116415       2017-03-06                    756   Bronx
# 4   bx-01-118956       2016-12-22                    830   Bronx
# 5   bx-01-123228       2017-03-30                    732   Bronx
# 33  bx-01-118955       2016-12-22                    830   Bronx
# 40  bx-01-123208       2017-10-26                    522   Bronx
#
#     Community Board   Latitude  Longitude       Street Address  Zip Code  \
# 0               201  40.816751 -73.922955    522 MORRIS AVENUE     10451
# 4               201  40.816679 -73.916483        2882 3 AVENUE     10455
# 5               201  40.816692 -73.919637  349 EAST 149 STREET     10451
# 33              201  40.817141 -73.916208        2901 3 AVENUE     10455
# 40              201  40.816692 -73.916719        2883 3 AVENUE     10455
#
#     EBT Total Calls      ...                     id      id2  \
# 0              3900      ...       7950000US3603710  3603710
# 4              1788      ...       7950000US3603710  3603710
# 5              1747      ...       7950000US3603710  3603710
# 33              929      ...       7950000US3603710  3603710
# 40              826      ...       7950000US3603710  3603710
#
#                                             geography  \
# 0   NYC-Bronx Community District 1 & 2--Hunts Poin...
# 4   NYC-Bronx Community District 1 & 2--Hunts Poin...
# 5   NYC-Bronx Community District 1 & 2--Hunts Poin...
# 33  NYC-Bronx Community District 1 & 2--Hunts Poin...
# 40  NYC-Bronx Community District 1 & 2--Hunts Poin...
#
#     total_estimate_households  \
# 0                       50736
# 4                       50736
# 5                       50736
# 33                      50736
# 40                      50736
#
#    households_receiving_food_stamps/snap_estimate_households  \
# 0                                               26214
# 4                                               26214
# 5                                               26214
# 33                                              26214
# 40                                              26214
#
#     percent_households_receiving_food_stamps/snap_estimate_households  PUMA  \
# 0                                                51.7                  3710
# 4                                                51.7                  3710
# 5                                                51.7                  3710
# 33                                               51.7                  3710
# 40                                               51.7                  3710
#
#     puma    shape_area    shape_leng
# 0   3710  1.377966e+08  91086.012338
# 4   3710  1.377966e+08  91086.012338
# 5   3710  1.377966e+08  91086.012338
# 33  3710  1.377966e+08  91086.012338
# 40  3710  1.377966e+08  91086.012338
#
# [5 rows x 24 columns]

# %%
for i in list(EBT_FOODSTAMPS.columns):
    print(i)
# Out:
# Site ID
# ﻿Activation Date
# Days Since Activation
# Borough
# Community Board
# Latitude
# Longitude
# Street Address
# Zip Code
# EBT Total Calls
# EBT Calls Per Day
# lonlat
# geometry
# index_right
# id
# id2
# geography
# total_estimate_households
# households_receiving_food_stamps/snap_estimate_households
# percent_households_receiving_food_stamps/snap_estimate_households
# PUMA
# puma
# shape_area
# shape_leng

# %%
viz_ebs_avgs = EBT_FOODSTAMPS[['EBT Total Calls','EBT Calls Per Day','lonlat','percent_households_receiving_food_stamps/snap_estimate_households','Community Board','puma','geometry','geography']]

# %%
viz_ebs_avgs.head(10)
# Out:
#      EBT Total Calls  EBT Calls Per Day                       lonlat  \
# 0               3900           5.158730  (-73.92295481, 40.81675132)
# 4               1788           2.154217  (-73.91648285, 40.81667907)
# 5               1747           2.386612      (-73.919637, 40.816692)
# 33               929           1.119277   (-73.91620844, 40.8171412)
# 40               826           1.582375   (-73.91671907, 40.8166923)
# 41               821           2.325779  (-73.91917137, 40.81399752)
# 110              520           1.502890  (-73.92143417, 40.81089649)
# 112              518           1.644444  (-73.91900611, 40.80775593)
# 118              500           0.602410  (-73.91366803, 40.81948845)
# 135              463           0.681885      (-73.912327, 40.821437)
#
#      percent_households_receiving_food_stamps/snap_estimate_households  \
# 0                                                 51.7
# 4                                                 51.7
# 5                                                 51.7
# 33                                                51.7
# 40                                                51.7
# 41                                                51.7
# 110                                               51.7
# 112                                               51.7
# 118                                               51.7
# 135                                               51.7
#
#      Community Board  puma                                geometry  \
# 0                201  3710  POINT (-73.92295480999999 40.81675132)
# 4                201  3710  POINT (-73.91648284999999 40.81667907)
# 5                201  3710    POINT (-73.91963699999999 40.816692)
# 33               201  3710   POINT (-73.91620844000001 40.8171412)
# 40               201  3710         POINT (-73.91671907 40.8166923)
# 41               201  3710        POINT (-73.91917137 40.81399752)
# 110              201  3710        POINT (-73.92143417 40.81089649)
# 112              201  3710        POINT (-73.91900611 40.80775593)
# 118              201  3710        POINT (-73.91366803 40.81948845)
# 135              201  3710            POINT (-73.912327 40.821437)
#
#                                              geography
# 0    NYC-Bronx Community District 1 & 2--Hunts Poin...
# 4    NYC-Bronx Community District 1 & 2--Hunts Poin...
# 5    NYC-Bronx Community District 1 & 2--Hunts Poin...
# 33   NYC-Bronx Community District 1 & 2--Hunts Poin...
# 40   NYC-Bronx Community District 1 & 2--Hunts Poin...
# 41   NYC-Bronx Community District 1 & 2--Hunts Poin...
# 110  NYC-Bronx Community District 1 & 2--Hunts Poin...
# 112  NYC-Bronx Community District 1 & 2--Hunts Poin...
# 118  NYC-Bronx Community District 1 & 2--Hunts Poin...
# 135  NYC-Bronx Community District 1 & 2--Hunts Poin...

# %%
trimed_viz_ebs_avgs = viz_ebs_avgs[['geometry','geography','EBT Calls Per Day','puma']]

# %%
trimed_viz_ebs_avgs.head(10)
# Out:
#                                    geometry  \
# 0    POINT (-73.92295480999999 40.81675132)
# 4    POINT (-73.91648284999999 40.81667907)
# 5      POINT (-73.91963699999999 40.816692)
# 33    POINT (-73.91620844000001 40.8171412)
# 40          POINT (-73.91671907 40.8166923)
# 41         POINT (-73.91917137 40.81399752)
# 110        POINT (-73.92143417 40.81089649)
# 112        POINT (-73.91900611 40.80775593)
# 118        POINT (-73.91366803 40.81948845)
# 135            POINT (-73.912327 40.821437)
#
#                                              geography  EBT Calls Per Day  \
# 0    NYC-Bronx Community District 1 & 2--Hunts Poin...           5.158730
# 4    NYC-Bronx Community District 1 & 2--Hunts Poin...           2.154217
# 5    NYC-Bronx Community District 1 & 2--Hunts Poin...           2.386612
# 33   NYC-Bronx Community District 1 & 2--Hunts Poin...           1.119277
# 40   NYC-Bronx Community District 1 & 2--Hunts Poin...           1.582375
# 41   NYC-Bronx Community District 1 & 2--Hunts Poin...           2.325779
# 110  NYC-Bronx Community District 1 & 2--Hunts Poin...           1.502890
# 112  NYC-Bronx Community District 1 & 2--Hunts Poin...           1.644444
# 118  NYC-Bronx Community District 1 & 2--Hunts Poin...           0.602410
# 135  NYC-Bronx Community District 1 & 2--Hunts Poin...           0.681885
#
#      puma
# 0    3710
# 4    3710
# 5    3710
# 33   3710
# 40   3710
# 41   3710
# 110  3710
# 112  3710
# 118  3710
# 135  3710

# %%
grp_by = trimed_viz_ebs_avgs.groupby(['geography','puma'])['EBT Calls Per Day'].median().reset_index()

# %%
grp_by.head(5)
# Out:
#                                            geography  puma  EBT Calls Per Day
# 0  NYC-Bronx Community District 1 & 2--Hunts Poin...  3710           0.602410
# 1  NYC-Bronx Community District 3 & 6--Belmont, C...  3705           0.900583
# 2  NYC-Bronx Community District 4--Concourse, Hig...  3708           0.550000
# 3  NYC-Bronx Community District 5--Morris Heights...  3707           0.701755
# 4  NYC-Bronx Community District 7--Bedford Park, ...  3706           0.448522

# %%
foodstamps_puma.head()
# Out:
#                  id      id2  \
# 0  7950000US3603701  3603701
# 1  7950000US3603702  3603702
# 2  7950000US3603703  3603703
# 3  7950000US3603704  3603704
# 4  7950000US3603705  3603705
#
#                                            geography  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...
# 1  NYC-Bronx Community District 12--Wakefield, Wi...
# 2  NYC-Bronx Community District 10--Co-op City, P...
# 3  NYC-Bronx Community District 11--Pelham Parkwa...
# 4  NYC-Bronx Community District 3 & 6--Belmont, C...
#
#    total_estimate_households  \
# 0                      42374
# 1                      48495
# 2                      47551
# 3                      44518
# 4                      57417
#
#    households_receiving_food_stamps/snap_estimate_households  \
# 0                                               8439
# 1                                              11904
# 2                                               6714
# 3                                              11236
# 4                                              29250
#
#    percent_households_receiving_food_stamps/snap_estimate_households  PUMA  \
# 0                                               19.9                  3701
# 1                                               24.5                  3702
# 2                                               14.1                  3703
# 3                                               25.2                  3704
# 4                                               50.9                  3705
#
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002487
# 2  3703  2.670108e+08  303565.021099
# 3  3704  1.062129e+08   47970.901277
# 4  3705  1.224951e+08   68657.316149
#
#                                             geometry
# 0  POLYGON ((-73.89995351384715 40.91238343476548...
# 1  POLYGON ((-73.86948896192655 40.87798946841054...
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...
# 4  POLYGON ((-73.87045508990893 40.86663286876232...

# %%
foodstamps_ebt_percent = foodstamps_puma.merge(grp_by,on='puma')

# %%
foodstamps_ebt_percent.head()
# Out:
#                  id      id2  \
# 0  7950000US3603701  3603701
# 1  7950000US3603705  3603705
# 2  7950000US3603706  3603706
# 3  7950000US3603707  3603707
# 4  7950000US3603708  3603708
#
#                                          geography_x  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...
# 1  NYC-Bronx Community District 3 & 6--Belmont, C...
# 2  NYC-Bronx Community District 7--Bedford Park, ...
# 3  NYC-Bronx Community District 5--Morris Heights...
# 4  NYC-Bronx Community District 4--Concourse, Hig...
#
#    total_estimate_households  \
# 0                      42374
# 1                      57417
# 2                      45122
# 3                      45284
# 4                      49026
#
#    households_receiving_food_stamps/snap_estimate_households  \
# 0                                               8439
# 1                                              29250
# 2                                              19157
# 3                                              23023
# 4                                              22286
#
#    percent_households_receiving_food_stamps/snap_estimate_households  PUMA  \
# 0                                               19.9                  3701
# 1                                               50.9                  3705
# 2                                               42.5                  3706
# 3                                               50.8                  3707
# 4                                               45.5                  3708
#
#    puma    shape_area    shape_leng  \
# 0  3701  9.792852e+07  53227.144461
# 1  3705  1.224951e+08  68657.316149
# 2  3706  4.388687e+07  51799.404183
# 3  3707  4.228113e+07  37347.925798
# 4  3708  5.589695e+07  34852.437966
#
#                                             geometry  \
# 0  POLYGON ((-73.89995351384715 40.91238343476548...
# 1  POLYGON ((-73.87045508990893 40.86663286876232...
# 2  POLYGON ((-73.87772817661512 40.88345419508449...
# 3  POLYGON ((-73.89964261686002 40.86221043694765...
# 4  POLYGON ((-73.92478318783078 40.8447526648105,...
#
#                                          geography_y  EBT Calls Per Day
# 0  NYC-Bronx Community District 8--Riverdale, Fie...           0.652961
# 1  NYC-Bronx Community District 3 & 6--Belmont, C...           0.900583
# 2  NYC-Bronx Community District 7--Bedford Park, ...           0.448522
# 3  NYC-Bronx Community District 5--Morris Heights...           0.701755
# 4  NYC-Bronx Community District 4--Concourse, Hig...           0.550000

# %%
#visualize median EBT calls per day in NYC, notice that some pumas are missing. this is reflective of the fact that linknycs are not deployed in all tracts

# %%
fig = pl.figure(figsize = (18,15))
ax = fig.add_subplot(111)
foodstamps_ebt_percent.plot("EBT Calls Per Day",ax=ax,legend=True,linewidth=1,edgecolor='black')
ax.axis('off');
ax.set_title('Median EBT calls per day in NYC', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Median EBT calls per day in NYC')

# %%
#histogram_intersection = lambda a, b: np.minimum(a, b).sum().round(decimals=1)
foodstamps_ebt_percent[['EBT Calls Per Day','percent_households_receiving_food_stamps/snap_estimate_households']].corr()
# Out:
#                                                     EBT Calls Per Day  \
# EBT Calls Per Day                                            1.000000
# percent_households_receiving_food_stamps/snap_e...           0.801612
#
#                                                     percent_households_receiving_food_stamps/snap_estimate_households
# EBT Calls Per Day                                                                            0.801612
# percent_households_receiving_food_stamps/snap_e...                                           1.000000

# %%
merged_pd = pd.DataFrame(foodstamps_ebt_percent)
#merged_pd['EBT calls per day 100'] = merged_pd['EBT Calls Per Day']*100

# %%
fig = pl.figure(figsize = (15,15))
ax = fig.add_subplot(111)
merged_pd.plot.scatter(x='EBT Calls Per Day', y='percent_households_receiving_food_stamps/snap_estimate_households', c='DarkBlue',figsize=(15,15),ax=ax)
ax.set_title('Scatterplot of median EBT calls per day vs percentage of households receiving food stamps', fontsize=15)
pl.xlabel('Median EBT calls per day')
pl.ylabel('percentage of households receiving food stamps')
# Out:
# Text(0, 0.5, 'percentage of households receiving food stamps')

# %%
#the positive correlation above warrants i look into their relationship visually, there seems to be some points that tend to closer. indicating a possible pattern.

# %%
X=merged_pd[['EBT Calls Per Day','percent_households_receiving_food_stamps/snap_estimate_households']]
from sklearn.cluster import KMeans

# %%
SSE = []
for i in range(2,10):
    km = KMeans(n_clusters = i)
    res=km.fit(X)
    SSE.append(res.inertia_)
print(SSE)

plt.gca()
plt.plot(range(2,10),SSE)
plt.xlabel("Clusters")
plt.ylabel("Sum of squared errors")
plt.title("SSE vs. number of clusters")
plt.xlim(1.5,9.5)
plt.show()
# Out:
# [2188.526048521901, 733.9673118219195, 346.88824159402907, 219.85470981146284, 135.4019960780087, 82.0283363963713, 36.25505686562952, 29.231202451679817]

# %%
#based on the elbow plot, i would select 4 clusters

# %%
km = KMeans(random_state=234,n_clusters=4)
res=km.fit(X)

print('Cluster assignments:',res.labels_)
print('\nCluster centers:\n',res.cluster_centers_)
print('\nSum of squared errors:',res.inertia_)

# plot points and cluster assigments
plt.figure(figsize=(15,15))
plt.scatter(X['EBT Calls Per Day'],X['percent_households_receiving_food_stamps/snap_estimate_households'],c=res.labels_,cmap=plt.cm.cool)
pl.xlabel('Median EBT calls per day')
pl.ylabel('percentage of households receiving food stamps')
plt.show()
# Out:
# Cluster assignments: [0 1 1 1 1 1 3 0 0 3 2 2 2 2 0 2 2 2 0 3 3 2 2 0 1 3 0 0 0 0 2 0 0 2 2 0 0]
#
# Cluster centers:
#  [[ 0.18732037 21.37142857]
#  [ 0.62110772 47.38333333]
#  [ 0.08427742  7.7       ]
#  [ 0.38714038 32.14      ]]
#
# Sum of squared errors: 346.88824159402907

# %%
#visualizing the four clusters in the scatter plot

# %%
with_clusters = pd.concat((merged_pd,pd.DataFrame(res.labels_)),axis=1)

# %%
with_clusters = with_clusters.rename(columns={0:'clusters'})

# %%
with_clusters.head()
# Out:
#                  id      id2  \
# 0  7950000US3603701  3603701
# 1  7950000US3603705  3603705
# 2  7950000US3603706  3603706
# 3  7950000US3603707  3603707
# 4  7950000US3603708  3603708
#
#                                          geography_x  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...
# 1  NYC-Bronx Community District 3 & 6--Belmont, C...
# 2  NYC-Bronx Community District 7--Bedford Park, ...
# 3  NYC-Bronx Community District 5--Morris Heights...
# 4  NYC-Bronx Community District 4--Concourse, Hig...
#
#    total_estimate_households  \
# 0                      42374
# 1                      57417
# 2                      45122
# 3                      45284
# 4                      49026
#
#    households_receiving_food_stamps/snap_estimate_households  \
# 0                                               8439
# 1                                              29250
# 2                                              19157
# 3                                              23023
# 4                                              22286
#
#    percent_households_receiving_food_stamps/snap_estimate_households  PUMA  \
# 0                                               19.9                  3701
# 1                                               50.9                  3705
# 2                                               42.5                  3706
# 3                                               50.8                  3707
# 4                                               45.5                  3708
#
#    puma    shape_area    shape_leng  \
# 0  3701  9.792852e+07  53227.144461
# 1  3705  1.224951e+08  68657.316149
# 2  3706  4.388687e+07  51799.404183
# 3  3707  4.228113e+07  37347.925798
# 4  3708  5.589695e+07  34852.437966
#
#                                             geometry  \
# 0  POLYGON ((-73.89995351384715 40.91238343476548...
# 1  POLYGON ((-73.87045508990893 40.86663286876232...
# 2  POLYGON ((-73.87772817661512 40.88345419508449...
# 3  POLYGON ((-73.89964261686002 40.86221043694765...
# 4  POLYGON ((-73.92478318783078 40.8447526648105,...
#
#                                          geography_y  EBT Calls Per Day  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...           0.652961
# 1  NYC-Bronx Community District 3 & 6--Belmont, C...           0.900583
# 2  NYC-Bronx Community District 7--Bedford Park, ...           0.448522
# 3  NYC-Bronx Community District 5--Morris Heights...           0.701755
# 4  NYC-Bronx Community District 4--Concourse, Hig...           0.550000
#
#    EBT calls per day 100  clusters
# 0              65.296053         0
# 1              90.058332         1
# 2              44.852217         1
# 3              70.175457         1
# 4              55.000000         1

# %%
with_clusters_pd = gpd.GeoDataFrame(with_clusters, geometry="geometry")

# %%
fig = pl.figure(figsize = (18,15))
ax = fig.add_subplot(111)
with_clusters_pd .plot("clusters",ax=ax,categorical=True,legend=True,cmap='hot',linewidth=1,edgecolor='black')
ax.axis('off');
ax.set_title('Cluster Assignments', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Cluster Assignments')

# %%
#there doesn't seem an obvious geospatial pattern to me

# %%
with_clusters.groupby('clusters')[['percent_households_receiving_food_stamps/snap_estimate_households']].describe()
# Out:
#          percent_households_receiving_food_stamps/snap_estimate_households  \
#                                                                      count
# clusters
# 0                                                      14.0
# 1                                                       6.0
# 2                                                      12.0
# 3                                                       5.0
#
#
#                mean       std   min    25%    50%     75%   max
# clusters
# 0         21.371429  2.923493  15.0  20.00  21.05  23.225  26.0
# 1         47.383333  4.246606  42.5  43.55  48.15  50.875  51.7
# 2          7.700000  3.594946   2.8   4.80   7.75   9.550  14.0
# 3         32.140000  0.826438  31.1  31.60  32.10  32.800  33.1

# %%
with_clusters.groupby('clusters')[['EBT Calls Per Day']].describe()
# Out:
#          EBT Calls Per Day                                                    \
#                      count      mean       std       min       25%       50%
# clusters
# 0                     14.0  0.187320  0.165950  0.013035  0.100045  0.153045
# 1                      6.0  0.621108  0.160844  0.448522  0.530032  0.576205
# 2                     12.0  0.084277  0.097196  0.009166  0.021115  0.049673
# 3                      5.0  0.387140  0.178922  0.139935  0.265591  0.467742
#
#
#                75%       max
# clusters
# 0         0.247805  0.652961
# 1         0.676918  0.900583
# 2         0.096826  0.330258
# 3         0.485636  0.576797

# %%
#bassed on the mean, the clusters follow to some extent the same degree of ordering
#i.e. cluster (lowest to highest) 2 -> 0 ->  3 -> 1 for both percentage of households receiving food stamps and median EBT calls per day

# %%
#might be important ot check into the socio-economic factors affecting these neighborhood-clusters
